# %% [markdown]
# # RAG

# %% [markdown]
# ## Requirements

# %%
# %%capture
# !pip install transformers accelerate bitsandbytes langchain langchain-community sentence-transformers faiss-gpu pandas gdown

# %% [markdown]
# ## Dataset

# %%
import gdown

url = 'https://drive.google.com/uc?id=1Lq2zVJlN_B4kUAu4VafQ4jXMIQiAR9vI'
output = 'IMDB_crawled.json'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Lq2zVJlN_B4kUAu4VafQ4jXMIQiAR9vI
# From (redirected): https://drive.google.com/uc?id=1Lq2zVJlN_B4kUAu4VafQ4jXMIQiAR9vI&confirm=t&uuid=ae380bd2-8424-477b-9bca-07013e431db6
# To: /content/IMDB_crawled.json
# 100%|██████████| 292M/292M [00:01<00:00, 225MB/s]
# 'IMDB_crawled.json'

# %% [markdown]
# ## Config

# %%
class Config:
    EMBEDDING_MODEL_NAME="thenlper/gte-base"
    LLM_MODEL_NAME="HuggingFaceH4/zephyr-7b-beta"
    K = 5 # top K retrieval

# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd

df = pd.read_json('IMDB_crawled.json')

# %%
import os

os.makedirs('data', exist_ok=True)

# preprocess your data and only store the needed data as the context window for embedding model is limited

df.to_csv('data/imdb.csv', index=False)
df.head()
# Out:
#           id                                              title  \
# 0  tt0071562                              The Godfather Part II
# 1  tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 2  tt0110912                                       Pulp Fiction
# 3  tt0068646                                      The Godfather
# 4  tt0111161                           The Shawshank Redemption
#
#                                   first_page_summary release_year   mpaa  \
# 0  The early life and career of Vito Corleone in ...         1974      R
# 1  A meek Hobbit from the Shire and eight compani...         2001  PG-13
# 2  The lives of two mob hitmen, a boxer, a gangst...         1994      R
# 3  The aging patriarch of an organized crime dyna...         1972      R
# 4  Over the course of several years, two convicts...         1994      R
#
#                     budget gross_worldwide  rating               directors  \
# 0  $13,000,000 (estimated)     $47,962,683     9.0  [Francis Ford Coppola]
# 1  $93,000,000 (estimated)    $884,041,698     8.9         [Peter Jackson]
# 2   $8,000,000 (estimated)    $213,928,762     8.9     [Quentin Tarantino]
# 3   $6,000,000 (estimated)    $250,342,030     9.2  [Francis Ford Coppola]
# 4  $25,000,000 (estimated)     $28,904,232     9.3        [Frank Darabont]
#
#                           writers  \
# 0                            None
# 1                            None
# 2                            None
# 3                            None
# 4  [Stephen King, Frank Darabont]
#
#                                              stars  \
# 0       [Al Pacino, Robert De Niro, Robert Duvall]
# 1       [Elijah Wood, Ian McKellen, Orlando Bloom]
# 2  [John Travolta, Uma Thurman, Samuel L. Jackson]
# 3           [Marlon Brando, Al Pacino, James Caan]
# 4        [Tim Robbins, Morgan Freeman, Bob Gunton]
#
#                                        related_links  \
# 0  [https://imdb.com/title/tt0068646/?ref_=tt_sim...
# 1  [https://imdb.com/title/tt0167261/?ref_=tt_sim...
# 2  [https://imdb.com/title/tt0137523/?ref_=tt_sim...
# 3  [https://imdb.com/title/tt0071562/?ref_=tt_sim...
# 4  [https://imdb.com/title/tt0468569/?ref_=tt_sim...
#
#                                       languages           countries_of_origin  \
# 0  [English, Italian, Spanish, Latin, Sicilian]               [United States]
# 1                           [English, Sindarin]  [New Zealand, United States]
# 2                    [English, Spanish, French]               [United States]
# 3                     [English, Italian, Latin]               [United States]
# 4                                     [English]               [United States]
#
#                                            summaries  \
# 0  [The early life and career of Vito Corleone in...
# 1  [A meek Hobbit from the Shire and eight compan...
# 2  [The lives of two mob hitmen, a boxer, a gangs...
# 3  [The aging patriarch of an organized crime dyn...
# 4  [Over the course of several years, two convict...
#
#                                             synposis  \
# 0  [The Godfather Part II presents two parallel s...
# 1  [Galadriel (Cate Blanchett) (The Elven co-rule...
# 2  [Narrative structure\nPulp Fiction's narrative...
# 3  [In late summer 1945, guests are gathered for ...
# 4  [In 1947, Andy Dufresne (Tim Robbins), a banke...
#
#                                              reviews  \
# 0  [[Coppola's masterpiece is rivaled only by "Th...
# 1  [[Here is one film that lived up to its hype, ...
# 2  [[I like the bit with the cheeseburger. It mak...
# 3  [['The Godfather' is the pinnacle of flawless ...
# 4  [[The Shawshank Redemption is written and dire...
#
#                        genres
# 0              [Crime, Drama]
# 1  [Action, Adventure, Drama]
# 2              [Crime, Drama]
# 3              [Crime, Drama]
# 4                     [Drama]

# %%
import os
import re
os.makedirs('data', exist_ok=True)

# preprocess your data and only store the needed data as the context window for embedding model is limited
columns_to_keep = ['first_page_summary','genres']
df = df[columns_to_keep]
df.dropna(inplace=True)

def clean_text(text):
    text = text.lower()
    text = re.sub(r'\s+', ' ', text)  # Remove extra whitespace
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    return text

def clean_text_list(text_list):
    return [clean_text(text) for text in text_list]

df['first_page_summary'] = df['first_page_summary'].apply(clean_text)
df['genres'] = df['genres'].apply(clean_text_list)
df.to_csv('data/imdb.csv', index=False)
# Out:
# <ipython-input-6-b4ecdfbf6c86>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %% [markdown]
# ## Vectorizer

# %% [markdown]
# load the CSV file and vectorize the rows using HuggingFaceEmbeddings.
# Store the results using FAISS vectorstore.
# Save the vectorestore in a pickle file for future usages.

# %%
import pickle
from langchain.document_loaders.csv_loader import CSVLoader
from langchain.vectorstores.utils import DistanceStrategy
from langchain.vectorstores.faiss import FAISS

from langchain_community.embeddings import HuggingFaceEmbeddings

# load the csv
loader = CSVLoader(file_path='data/imdb.csv', encoding='utf-8')
documents = loader.load()

# load the embeddings model
embedding_model = HuggingFaceEmbeddings(model_name=Config.EMBEDDING_MODEL_NAME)

# save embed the documents using the model in a vectorstore
vectorstore = FAISS.from_documents(documents, embedding_model, distance_strategy=DistanceStrategy.COSINE)

# save embed the documents using the model in a vectorstore
with open("data/vectorstore.pkl", "wb") as f:
    pickle.dump(vectorstore, f)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/68.1k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/618 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/219M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# load the vectorstore as a retriever.

# %%
with open("data/vectorstore.pkl", "rb") as f:
    vectorstore = pickle.load(f)

# Load the retriever from the vectorstore
retriever = vectorstore.as_retriever()

print("Retriever loaded from vectorstore")
# Out:
# Retriever loaded from vectorstore

# %% [markdown]
# ## LLM

# %% [markdown]
# load the quantized LLM.

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU found")
# Out:
# True
# 1
# Tesla T4

# %%
import torch
import accelerate
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from transformers import pipeline

from langchain_community.llms.huggingface_pipeline import HuggingFacePipeline

# load the quantization config
bnb_config  = BitsAndBytesConfig()

model = AutoModelForCausalLM.from_pretrained(Config.LLM_MODEL_NAME, quantization_config=bnb_config, device_map="cuda:0")
tokenizer = AutoTokenizer.from_pretrained(Config.LLM_MODEL_NAME)

# init the pipeline
READER_LLM = pipeline(
    task="text-generation",
    model=model,
    tokenizer=tokenizer,
    max_length=512
)

llm = HuggingFacePipeline(
    pipeline=READER_LLM,
)
# Out:
# config.json:   0%|          | 0.00/638 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/8 [00:00<?, ?it/s]
# model-00001-of-00008.safetensors:   0%|          | 0.00/1.89G [00:00<?, ?B/s]
# model-00002-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00003-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00004-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00005-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00006-of-00008.safetensors:   0%|          | 0.00/1.95G [00:00<?, ?B/s]
# model-00007-of-00008.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00008-of-00008.safetensors:   0%|          | 0.00/816M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/168 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 0.3. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFacePipeline`.
#   warn_deprecated(

# %% [markdown]
# initialize the prompt template for the query chain. query chain is used to get a query from the chat history. you may change the prompt as you like to get better results.

# %%
from langchain.prompts import PromptTemplate

from langchain_core.output_parsers import StrOutputParser

from langchain_core.runnables import RunnablePassthrough


class LoggerStrOutputParser(StrOutputParser):
    def parse(self, text: str) -> str:
        # process the LLM output
        processed_text = text.strip()
        print(f"QUERY: {processed_text}")
        return processed_text

query_transform_prompt = PromptTemplate(
    input_variables=["messages"],
    template="""<|system|>You are a helpful assistant.
{messages}
<|user|>
give me the search query about the above conversation.
<|assistant|>"""
)

# init the query chain
query_transforming_retriever_chain = (
    {"messages": RunnablePassthrough()}
    | query_transform_prompt
    | llm
    | StrOutputParser()
)

# %% [markdown]
# initialize the main retrieval chain that gives the resulting documents to LLM and gets the output back.

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import RetrievalQA
from langchain_core.runnables import RunnablePassthrough

prompt = PromptTemplate(
    input_variables=["context", "messages"],
    template="""<|system|>You are a helpful assistant.

Here are the movies you MUST choose from:

{context}
-----------------
{messages}
<|assistant|>""")

# init the retriver chain
retrieval_chain =  (
    {"context" : retriever, "messages": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %% [markdown]
# write the conversation helper class for easier testing.

# %%
from langchain.schema import Document
class Conversation:
    def __init__(self):
        self.messages = []

    def add_assistant_message(self, message):
        self.messages.append(('assistant', message))

    def add_user_message(self, message):
        self.messages.append(('user', message))

    def add_quest_ans(self, quest, res):
        temp = "question : \"" + quest + "\"   answer : " + res
        self.messages.append(temp)

    def get_messages(self,mess):
        # concatenate the messages with the roles in the instruction format
        messages = ""
        for mess in self.messages:
            messages += (mess + "\n")
        messages += "query : \"" + mess + "\""
        return messages
    def chat(self, message):
        messages = self.get_messages(message)
        # Run query transforming retriever chain
        output = query_transforming_retriever_chain.invoke({"messages": messages})
        responseout = output.split("<|assistant|>")[1]
        results = retrieval_chain.invoke(responseout)
        res = results.split("<|assistant|>")[1]
        self.add_quest_ans(message, res)
        print("RESULT : ", results)

# %% [markdown]
# ## Test

# %% [markdown]
# talk with the RAG to see how good it performs.

# %%
c = Conversation()
A = c.chat('give me a cool gangster movie')
print(A)
# Out:
# RESULT :  <|system|>You are a helpful assistant.
#
# Here are the movies you MUST choose from:
#
# [Document(page_content="first_page_summary: an aspiring director targets a ruthless gangster because he wants to make a violent gangster film his discreet attempts to research the gangster fail miserably finally when he gets caught  read all\ngenres: ['action', 'comedy', 'crime']", metadata={'source': 'data/imdb.csv', 'row': 4627}), Document(page_content="first_page_summary: an ambitious and nearly insane violent gangster climbs the ladder of success in the mob but his weaknesses prove to be his downfall\ngenres: ['action', 'crime', 'drama']", metadata={'source': 'data/imdb.csv', 'row': 369}), Document(page_content="first_page_summary: in 1975 a filmmaker agrees to collaborate on a film with a gangster who wishes to become a famous actor\ngenres: ['action', 'comedy', 'drama']", metadata={'source': 'data/imdb.csv', 'row': 1978}), Document(page_content="first_page_summary: a tough police officer sets out to track down and kill an equally tough gangster\ngenres: ['action', 'crime', 'drama']", metadata={'source': 'data/imdb.csv', 'row': 3411})]
# -----------------
#
# "Recommend a stylish and thrilling gangster movie based on the conversation 'query : "give me a cool gangster movie"'"
# <|assistant|>
# Based on the conversation "query : 'give me a cool gangster movie'", I would recommend the movie "Pulp Fiction" (1994) directed by Quentin Tarantino. While it's not explicitly a gangster movie, it features several gangster elements and is widely regarded as a stylish and thrilling portrayal of the criminal underworld. The movie's nonlinear narrative structure, iconic dialogue, and memorable performances by its star-studded cast, including John Travolta, Samuel L. Jackson, and Uma Thurman, make it a must-watch for any fan
# None

# %%
A = c.chat('give me a newer one')
print(A)
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# RESULT :  <|system|>You are a helpful assistant.
#
# Here are the movies you MUST choose from:
#
# [Document(page_content="first_page_summary: in 1975 a filmmaker agrees to collaborate on a film with a gangster who wishes to become a famous actor\ngenres: ['action', 'comedy', 'drama']", metadata={'source': 'data/imdb.csv', 'row': 1978}), Document(page_content="first_page_summary: an aspiring director targets a ruthless gangster because he wants to make a violent gangster film his discreet attempts to research the gangster fail miserably finally when he gets caught  read all\ngenres: ['action', 'comedy', 'crime']", metadata={'source': 'data/imdb.csv', 'row': 4627}), Document(page_content="first_page_summary: this is quentin tarantinos early reservoir dogs film as to what helped fuel his feature length version\ngenres: ['short', 'drama']", metadata={'source': 'data/imdb.csv', 'row': 354}), Document(page_content="first_page_summary: a tough police officer sets out to track down and kill an equally tough gangster\ngenres: ['action', 'crime', 'drama']", metadata={'source': 'data/imdb.csv', 'row': 3411})]
# -----------------
#
# "query : 'give me a cool gangster movie'", as mentioned in the conversation, can be used as a search query to find recommendations for a stylish and thrilling gangster movie, as suggested by the helpful assistant in the conversation. The recommended movie in this case is "Pulp Fiction" (1994) directed by Quentin Tarantino.
# <|assistant|>
# However, based on the movie summaries provided, I would suggest the following movies as alternatives:
#
# 1. "Once Upon a Time in America" (1996) directed by Sergio Leone
# 2. "Goodfellas" (1990) directed by Martin Scorsese
# 3. "Scarface" (1983) directed by Brian De Palma
# 4. "The Godfather" (19
# None
